# %% [markdown]
# ### Importación de Librerias

# %%
import pandas as pd
import seaborn as sns
import toolbox_ML as tb
import warnings

warnings.filterwarnings('ignore')

# Configurar pandas para que no corte las visualizaciones
pd.set_option("display.max_columns", None)  # Mostrar todas las columnas
pd.set_option("display.max_colwidth", None)  # Mostrar todo el contenido de las celdas, si es posible
# pd.set_option('display.max_rows', None) # Mostrar todas las filas

# %% [markdown]
# ### Creando el dataframe

# %%
df = pd.read_csv("../data/F1_act.csv")

# %% [markdown]
# ### EDA

# %%
sns.pairplot(df[['Race', 'Driver', 'Constructor', 'Circuit', 'Grid', 'Position_Order',
       'Points', 'Laps', 'Fastest_Lap', 'Rank', 'Fastest_Lap_Time (Seg)',
       'Fastest_Lap_Speed (KM/H)', 'Status', 'Year', 'Date']])

# %% [markdown]
# ![Cnstrctr - Scatter PositionorderFastestlap.png](<attachment:Cnstrctr - Scatter PositionorderFastestlap.png>)

# %% [markdown]
# ![Cnstrctr - Scatter Positionorderfastestlapspeed.png](<attachment:Cnstrctr - Scatter Positionorderfastestlapspeed.png>)

# %% [markdown]
# ![Cnstrctr - Scatter PositionorderPoints.png](<attachment:Cnstrctr - Scatter PositionorderPoints.png>)

# %% [markdown]
# ![Constructor - Grid 10 años actuales.png](<attachment:Constructor - Grid 10 años actuales.png>)

# %% [markdown]
# ![Constructor - Grid 10 años.png](<attachment:Constructor - Grid 10 años.png>)

# %% [markdown]
# ![Constructor Rank Bump Chart.png](<attachment:Constructor Rank Bump Chart.png>)

# %% [markdown]
# ![Driver - Grid 10 años actuales.png](<attachment:Driver - Grid 10 años actuales.png>)

# %% [markdown]
# ![Drvr - Scatter PositionorderFastestlap.png](<attachment:Drvr - Scatter PositionorderFastestlap.png>)

# %% [markdown]
# ![Drvr - Scatter Positionorderfastestlapspeed.png](<attachment:Drvr - Scatter Positionorderfastestlapspeed.png>)

# %% [markdown]
# ![Drvr - Scatter PositionorderGrid.png](<attachment:Drvr - Scatter PositionorderGrid.png>)

# %% [markdown]
# ![Drvr - Scatter PositionorderPoints.png](<attachment:Drvr - Scatter PositionorderPoints.png>)

# %% [markdown]
# ![GP - Fastest Lap Time 1.png](<attachment:GP - Fastest Lap Time 1.png>)

# %% [markdown]
# ![GP - Fastest Lap Time 2.png](<attachment:GP - Fastest Lap Time 2.png>)

# %% [markdown]
# ![GP - Fastest Lap Time 3.png](<attachment:GP - Fastest Lap Time 3.png>)

# %% [markdown]
# ![GP - Fastest Lap Time 4.png](<attachment:GP - Fastest Lap Time 4.png>)

# %% [markdown]
# ![Top 10 - All Time.png](<attachment:Top 10 - All Time.png>)

# %% [markdown]
# ![Top 10 - Ultimos 10 años.png](<attachment:Top 10 - Ultimos 10 años.png>)
